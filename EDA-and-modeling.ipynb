# %%
import pandas as pd
import numpy as np
import seaborn as sns

df_client = pd.read_csv('data/client_train.csv')
df_invoice = pd.read_csv('data/invoice_train.csv')

# Merge the datasets on 'Client_id'
df = pd.merge(df_client, df_invoice, on='client_id', how='left')
# Out:
# C:\Users\nourk\AppData\Local\Temp\ipykernel_11480\2744559384.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_invoice = pd.read_csv('data/invoice_train.csv')

# %%
import data_processing_utils as dpu

# %%
dpu.analyze_data(df,df.target)
# Out:
# Display some values from the dataframe:
#    disrict       client_id  client_catg  region creation_date  target
# 0       60  train_Client_0           11     101    31/12/1994     0.0  \
# 1       60  train_Client_0           11     101    31/12/1994     0.0
# 2       60  train_Client_0           11     101    31/12/1994     0.0
# 3       60  train_Client_0           11     101    31/12/1994     0.0
# 4       60  train_Client_0           11     101    31/12/1994     0.0
#
#   invoice_date  tarif_type  counter_number counter_statue  ...
# 0   2014-03-24          11         1335667              0  ...  \
# 1   2013-03-29          11         1335667              0  ...
# 2   2015-03-23          11         1335667              0  ...
# 3   2015-07-13          11         1335667              0  ...
# 4   2016-11-17          11         1335667              0  ...
#
#    reading_remarque  counter_coefficient  consommation_level_1
# 0                 8                    1                    82  \
# 1                 6                    1                  1200
# 2                 8                    1                   123
# 3                 8                    1                   102
# 4                 9                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4
# 0                     0                     0                     0  \
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number  counter_type
# 0      14302      14384              4          ELEC
# 1      12294      13678              4          ELEC
# 2      14624      14747              4          ELEC
# 3      14747      14849              4          ELEC
# 4      15066      15638             12          ELEC
#
# [5 rows x 21 columns]
# ----------
# Dataframe Shape: (4476749, 21)
# ----------
# Dataframe Descriptive Statistics:
#                           count          mean           std    min       25%
# disrict               4476749.0  6.348246e+01  3.273403e+00   60.0      62.0  \
# client_catg           4476749.0  1.194381e+01  6.022452e+00   11.0      11.0
# region                4476749.0  2.103584e+02  1.035828e+02  101.0     103.0
# target                4476749.0  7.887688e-02  2.695465e-01    0.0       0.0
# tarif_type            4476749.0  2.012804e+01  1.347256e+01    8.0      11.0
# counter_number        4476749.0  1.230587e+11  1.657267e+12    0.0  121108.0
# counter_code          4476749.0  1.724884e+02  1.338871e+02    0.0       5.0
# reading_remarque      4476749.0  7.321702e+00  1.571654e+00    5.0       6.0
# counter_coefficient   4476749.0  1.003040e+00  3.083466e-01    0.0       1.0
# consommation_level_1  4476749.0  4.109795e+02  7.573080e+02    0.0      79.0
# consommation_level_2  4476749.0  1.093225e+02  1.220123e+03    0.0       0.0
# consommation_level_3  4476749.0  2.030620e+01  1.574239e+02    0.0       0.0
# consommation_level_4  4476749.0  5.292588e+01  8.754725e+02    0.0       0.0
# old_index             4476749.0  1.776700e+04  4.036693e+04    0.0    1791.0
# new_index             4476749.0  1.834970e+04  4.095321e+04    0.0    2056.0
# months_number         4476749.0  4.483095e+01  3.128335e+03    0.0       4.0
#
#                            50%        75%           max
# disrict                   62.0       63.0  6.900000e+01
# client_catg               11.0       11.0  5.100000e+01
# region                   301.0      309.0  3.990000e+02
# target                     0.0        0.0  1.000000e+00
# tarif_type                11.0       40.0  4.500000e+01
# counter_number        494561.0  1115161.0  2.798115e+13
# counter_code             203.0      207.0  6.000000e+02
# reading_remarque           8.0        9.0  4.130000e+02
# counter_coefficient        1.0        1.0  5.000000e+01
# consommation_level_1     274.0      600.0  9.999100e+05
# consommation_level_2       0.0        0.0  9.990730e+05
# consommation_level_3       0.0        0.0  6.449200e+04
# consommation_level_4       0.0        0.0  5.479460e+05
# old_index               7690.0    21660.0  2.800280e+06
# new_index               8192.0    22343.0  2.870972e+06
# months_number              4.0        4.0  6.366240e+05
# ----------
# Unique values from each column:
# disrict                      4
# client_id               135493
# client_catg                  3
# region                      25
# creation_date             8088
# target                       2
# invoice_date              8275
# tarif_type                  17
# counter_number          201893
# counter_statue              16
# counter_code                42
# reading_remarque             8
# counter_coefficient         16
# consommation_level_1      8295
# consommation_level_2     12576
# consommation_level_3      2253
# consommation_level_4     12075
# old_index               155648
# new_index               157980
# months_number             1370
# counter_type                 2
# dtype: int64
# ----------
# Checking for duplicates
# Data has 11 duplicates
# ----------
# c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\missingno\missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(

# %% [markdown]
# ### view duplicated data

# %%
# Check for duplicates
duplicated_rows = df[df.duplicated(keep=False)]

# Create a new DataFrame with duplicated rows
duplicated_df = pd.DataFrame(duplicated_rows)

# Get duplicated columns
duplicated_columns = duplicated_df.columns[duplicated_df.duplicated()]

duplicated_df.head(30)
# Out:
#          disrict            client_id  client_catg  region creation_date
# 951890        60  train_Client_125864           11     101    29/12/1998  \
# 951893        60  train_Client_125864           11     101    29/12/1998
# 1755789       62   train_Client_25894           11     301    16/06/1995
# 1755798       62   train_Client_25894           11     301    16/06/1995
# 2137995       60    train_Client_3636           11     101    21/11/1988
# 2137999       60    train_Client_3636           11     101    21/11/1988
# 2163371       60   train_Client_37069           11     101    09/03/1990
# 2163374       60   train_Client_37069           11     101    09/03/1990
# 2433907       60   train_Client_44407           11     101    15/06/1989
# 2433919       60   train_Client_44407           11     101    15/06/1989
# 2805727       60   train_Client_54609           11     101    16/02/1994
# 2805729       60   train_Client_54609           11     101    16/02/1994
# 3260190       63   train_Client_66981           51     313    20/11/1996
# 3260191       63   train_Client_66981           51     313    20/11/1996
# 3260198       63   train_Client_66981           51     313    20/11/1996
# 3394717       62    train_Client_7066           11     304    12/04/2013
# 3394719       62    train_Client_7066           11     304    12/04/2013
# 3462928       60   train_Client_72519           11     101    03/06/1982
# 3462929       60   train_Client_72519           11     101    03/06/1982
# 3628813       63   train_Client_77029           51     312    27/02/2010
# 3628821       63   train_Client_77029           51     312    27/02/2010
#
#          target invoice_date  tarif_type  counter_number counter_statue  ...
# 951890      0.0   2011-12-12          11          101545              5  ...  \
# 951893      0.0   2011-12-12          11          101545              5  ...
# 1755789     0.0   2010-07-13          40         6986740              5  ...
# 1755798     0.0   2010-07-13          40         6986740              5  ...
# 2137995     0.0   2012-01-18          40          312650              5  ...
# 2137999     0.0   2012-01-18          40          312650              5  ...
# 2163371     0.0   2010-10-11          11            5284              5  ...
# 2163374     0.0   2010-10-11          11            5284              5  ...
# 2433907     1.0   2008-02-28          11           66921              5  ...
# 2433919     1.0   2008-02-28          11           66921              5  ...
# 2805727     0.0   2010-04-06          11          200912              5  ...
# 2805729     0.0   2010-04-06          11          200912              5  ...
# 3260190     1.0   2006-07-17          11          132701              5  ...
# 3260191     1.0   2006-07-17          11          132701              5  ...
# 3260198     1.0   2006-07-17          11          132701              5  ...
# 3394717     0.0   2014-10-28          40         4463323              5  ...
# 3394719     0.0   2014-10-28          40         4463323              5  ...
# 3462928     0.0   2013-01-21          11          246464              5  ...
# 3462929     0.0   2013-01-21          11          246464              5  ...
# 3628813     0.0   2012-12-28          11          540417              5  ...
# 3628821     0.0   2012-12-28          11          540417              5  ...
#
#          reading_remarque  counter_coefficient  consommation_level_1
# 951890                  6                    1                     0  \
# 951893                  6                    1                     0
# 1755789                 6                    1                     0
# 1755798                 6                    1                     0
# 2137995                 6                    1                     0
# 2137999                 6                    1                     0
# 2163371                 6                    1                     0
# 2163374                 6                    1                     0
# 2433907                 6                    1                     0
# 2433919                 6                    1                     0
# 2805727                 6                    1                     0
# 2805729                 6                    1                     0
# 3260190                 6                    1                     0
# 3260191                 6                    1                     0
# 3260198                 6                    1                     0
# 3394717                 6                    1                     0
# 3394719                 6                    1                     0
# 3462928                 6                    1                     0
# 3462929                 6                    1                     0
# 3628813                 6                    1                     0
# 3628821                 6                    1                     0
#
#          consommation_level_2  consommation_level_3  consommation_level_4
# 951890                      0                     0                     0  \
# 951893                      0                     0                     0
# 1755789                     0                     0                     0
# 1755798                     0                     0                     0
# 2137995                     0                     0                     0
# 2137999                     0                     0                     0
# 2163371                     0                     0                     0
# 2163374                     0                     0                     0
# 2433907                     0                     0                     0
# 2433919                     0                     0                     0
# 2805727                     0                     0                     0
# 2805729                     0                     0                     0
# 3260190                     0                     0                     0
# 3260191                     0                     0                     0
# 3260198                     0                     0                     0
# 3394717                     0                     0                     0
# 3394719                     0                     0                     0
# 3462928                     0                     0                     0
# 3462929                     0                     0                     0
# 3628813                     0                     0                     0
# 3628821                     0                     0                     0
#
#          old_index  new_index  months_number  counter_type
# 951890       13680      13680              2          ELEC
# 951893       13680      13680              2          ELEC
# 1755789          0          0              2           GAZ
# 1755798          0          0              2           GAZ
# 2137995        623        623              2           GAZ
# 2137999        623        623              2           GAZ
# 2163371      99429      99429              2          ELEC
# 2163374      99429      99429              2          ELEC
# 2433907          0          0              2          ELEC
# 2433919          0          0              2          ELEC
# 2805727          0          0              2          ELEC
# 2805729          0          0              2          ELEC
# 3260190       5946       5946              2          ELEC
# 3260191       5946       5946              2          ELEC
# 3260198       5946       5946              2          ELEC
# 3394717         80         80              2           GAZ
# 3394719         80         80              2           GAZ
# 3462928       2954       2954              2          ELEC
# 3462929       2954       2954              2          ELEC
# 3628813      26429      26429              2          ELEC
# 3628821      26429      26429              2          ELEC
#
# [21 rows x 21 columns]

# %% [markdown]
# &rarr; this data is just duplicated and is not useful  so the duplicated rows are going to be dropped.

# %% [markdown]
# ### Check for outliers

# %% [markdown]
# in the context of fraud detection outliers are very important individuals in the data that should be kept

# %% [markdown]
# ### Check the percentage of zeros in each column

# %%
# Calculate percentage of zeros in each feature
zero_percentages = (df == 0).mean() * 100

# Print percentage of zeros for each feature
print("Percentage of zeros in each feature:")
print(zero_percentages)
# Out:
# Percentage of zeros in each feature:
# disrict                  0.000000
# client_id                0.000000
# client_catg              0.000000
# region                   0.000000
# creation_date            0.000000
# target                  92.112312
# invoice_date             0.000000
# tarif_type               0.000000
# counter_number           0.964115
# counter_statue          97.100820
# counter_code             0.000737
# reading_remarque         0.000000
# counter_coefficient      0.001028
# consommation_level_1    10.444030
# consommation_level_2    85.244426
# consommation_level_3    95.904215
# consommation_level_4    97.923538
# old_index                6.431140
# new_index                4.376636
# months_number            0.000045
# counter_type             0.000000
# dtype: float64

# %% [markdown]
# __Observations:__
# - **target** has  92.112312% of zeros : this due to a huge data imbalance in the target variable which will be addressed later
# - **counter_statue** has 97.100820% of zeros: this a good sign since 0 means that the counter is working fine.
# - **counter_code** and **month_number** have a very small percentages of zeros (maybe we can perform imputation on those variables )
# - **old_index** and **new_index**  are to be discussed
#
# __Note__: to be able to perform imputation we need to convert the zeros to nulls

# %% [markdown]
# ### Search for inconsistent data

# %%
df.dtypes
# Out:
# disrict                          int64
# client_id                       object
# client_catg                      int64
# region                           int64
# creation_date           datetime64[ns]
# target                         float64
# invoice_date            datetime64[ns]
# tarif_type                       int64
# counter_number                   int64
# counter_statue                  object
# counter_code                     int64
# reading_remarque                 int64
# counter_coefficient              int64
# consommation_level_1             int64
# consommation_level_2             int64
# consommation_level_3             int64
# consommation_level_4             int64
# old_index                        int64
# new_index                        int64
# months_number                    int64
# counter_type                    object
# dtype: object

# %% [markdown]
# after having a look into the data types : the __objects__ variables seem very suspicious.
# - client id : it okay to have it as a object since it is a string
# - creation_date and invoice_date should be converted to a date value for later manipulations
# - counter_statue : it is an int in the range of (5)
# - counter_type: is a string ['ELEC' 'GAZ']
#
# __float__
# - target: should be an int since it only takes 0 or 1

# %%
# verify how consistent "counter_statue" is 
unique_entries = df['counter_statue'].unique()
print(unique_entries)
# Out:
# [0 1 5 4 3 2 769 '0' '5' '1' '4' 'A' 618 269375 46 420]

# %% [markdown]
# the counter_statue is an int between 0 and 5 but in the data set we have those [0 1 5 4 3 2 769 '0' '5' '1' '4' 'A' 618 269375 46 420].
#
# &rarr; we should find a way to replace the inconsistent data

# %%
#verify the consistency of tarif_type
unique_entries = df['tarif_type'].unique()
print(unique_entries)
# [11 40 15 10 12 14 13 45 29  9 30  8 21 42 27 18 24] : the result seems correct
# Out:
# [11 40 15 10 12 14 13 45 29  9 30  8 21 42 27 18 24]

# %%
#verify the consistency of "disrict"
unique_entries = df['disrict'].unique()
print(unique_entries)
# [60 69 62 63]: seems correct
# Out:
# [60 69 62 63]

# %%
#verify the consistency of "client_catg"
unique_entries = df['client_catg'].unique()
print(unique_entries)
# [11 12 51]: seems correct
# Out:
# [11 12 51]

# %%
#verify the consistency of "counter_type"
unique_entries = df['counter_type'].unique()
print(unique_entries)
# ['ELEC' 'GAZ']: correst values
# Out:
# ['ELEC' 'GAZ']

# %% [markdown]
# ### Searching for patterns in the data distribution

# %%
# Categorical Variables
categorical_vars = [
    'client_id', 'district', 'client_catg', 'region', 'target', 
    'tarif_type', 'counter_number', 'counter_statue', 'counter_code', 
    'reading_remarque', 'counter_type'
]
# Numerical Variables
numerical_vars = [
    'counter_coefficient', 'consommation_level_1', 'consommation_level_2', 
    'consommation_level_3', 'consommation_level_4', 'old_index', 'new_index', 
    'months_number'
]

# %%
# Pair Plot for numerical variables
sns.pairplot(df[numerical_vars])
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = df[numerical_vars].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# # Data cleaningin and feature engineering

# %%
# Convert date columns to datetime
df['creation_date'] = pd.to_datetime(df['creation_date'], format='%d/%m/%Y')
df['invoice_date'] = pd.to_datetime(df['invoice_date'])

# Convert target from float to int 
df['target'] = df['target'].astype(int)

# %%
df.dtypes
# Out:
# disrict                          int64
# client_id                       object
# client_catg                      int64
# region                           int64
# creation_date           datetime64[ns]
# target                           int32
# invoice_date            datetime64[ns]
# tarif_type                       int64
# counter_number                   int64
# counter_statue                  object
# counter_code                     int64
# reading_remarque                 int64
# counter_coefficient              int64
# consommation_level_1             int64
# consommation_level_2             int64
# consommation_level_3             int64
# consommation_level_4             int64
# old_index                        int64
# new_index                        int64
# months_number                    int64
# counter_type                    object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 11
#       9 categorical_features = ['disrict', 'client_catg', 'region', 'tarif_type', 'counter_statue', 'counter_type']
#      10 for feature in categorical_features:
# ---> 11     sns.countplot(df[feature])
#      12     plt.show()
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\categorical.py:516, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\categorical.py:516, in <listcomp>(.0)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\pandas\core\series.py:917, in Series.__array__(self, dtype)
#     870 """
#     871 Return the values as a NumPy array.
#     872
#    (...)
#     914       dtype='datetime64[ns]')
#     915 """
#     916 values = self._values
# --> 917 arr = np.asarray(values, dtype=dtype)
#     918 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     919     arr = arr.view()
#
# ValueError: could not convert string to float: 'A'

# %%
# Extract numeric part and convert to integer
df['client_id'] = df['client_id'].str.split('-').str[1].astype(int)
# Correlation matrix
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Extract numeric part and convert to integer
# ----> 2 df['client_id'] = df['client_id'].str.split('-').str[1].astype(int)
#       3 # Correlation matrix
#       4 correlation_matrix = df.corr()
#
# NameError: name 'df' is not defined

# %%
# Pairplot for a subset of features
sns.pairplot(df[['consommation_level_1', 'consommation_level_2', 'consommation_level_3', 'consommation_level_4', 'target']], hue='target')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Pairplot for a subset of features
# ----> 2 sns.pairplot(df[['consommation_level_1', 'consommation_level_2', 'consommation_level_3', 'consommation_level_4', 'target']], hue='target')
#       3 plt.show()
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\axisgrid.py:2158, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2156 if kind == "scatter":
#    2157     from .relational import scatterplot  # Avoid circular import
# -> 2158     plotter(scatterplot, **plot_kws)
#    2159 elif kind == "reg":
#    2160     from .regression import regplot  # Avoid circular import
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\axisgrid.py:1421, in PairGrid.map_offdiag(self, func, **kwargs)
#    1419     self.map_lower(func, **kwargs)
#    1420     if not self._corner:
# -> 1421         self.map_upper(func, **kwargs)
#    1422 else:
#    1423     indices = []
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\axisgrid.py:1404, in PairGrid.map_upper(self, func, **kwargs)
#    1393 """Plot with a bivariate function on the upper diagonal subplots.
#    1394
#    1395 Parameters
#    (...)
#    1401
#    1402 """
#    1403 indices = zip(*np.triu_indices_from(self.axes, 1))
# -> 1404 self._map_bivariate(func, indices, **kwargs)
#    1405 return self
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\axisgrid.py:1568, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1566     if ax is None:  # i.e. we are in corner mode
#    1567         continue
# -> 1568     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1569 self._add_axis_labels()
#    1571 if "hue" in signature(func).parameters:
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\axisgrid.py:1609, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1605 if "hue" not in kwargs:
#    1606     kwargs.update({
#    1607         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1608     })
# -> 1609 func(x=x, y=y, **kwargs)
#    1611 self._update_legend_data(ax)
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\relational.py:761, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     758 color = kwargs.pop("color", None)
#     759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 761 p.plot(ax, kwargs)
#     763 return ax
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\seaborn\relational.py:578, in _ScatterPlotter.plot(self, ax, kws)
#     575 # Apply the mapping from semantic variables to artist attributes
#     577 if "hue" in self.variables:
# --> 578     points.set_facecolors(self._hue_map(data["hue"]))
#     580 if "size" in self.variables:
#     581     points.set_sizes(self._size_map(data["size"]))
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\matplotlib\_api\__init__.py:256, in define_aliases.<locals>.make_alias.<locals>.method(self, *args, **kwargs)
#     254 @functools.wraps(getattr(cls, name))
#     255 def method(self, *args, **kwargs):
# --> 256     return getattr(self, name)(*args, **kwargs)
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\matplotlib\collections.py:751, in Collection.set_facecolor(self, c)
#     749     c = c.lower()
#     750 self._original_facecolor = c
# --> 751 self._set_facecolor(c)
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\matplotlib\collections.py:733, in Collection._set_facecolor(self, c)
#     730 if c is None:
#     731     c = self._get_default_facecolor()
# --> 733 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     734 self.stale = True
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\matplotlib\colors.py:481, in to_rgba_array(c, alpha)
#     479 lens = {len(cc) if isinstance(cc, (list, tuple)) else -1 for cc in c}
#     480 if lens == {3}:
# --> 481     rgba = np.column_stack([c, np.ones(len(c))])
#     482 elif lens == {4}:
#     483     rgba = np.array(c)
#
# File <__array_function__ internals>:200, in column_stack(*args, **kwargs)
#
# File c:\Users\nourk\spicedAcademy\ElectroThunderFraud\.venv\Lib\site-packages\numpy\lib\shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Splitting data for testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
#dropping Quakers column and unnamed
#changing one of the altitude to log and droping the original
X_train["altitude_mean_log"] = np.log(X_train["altitude_mean_meters"])
X_train.drop(['altitude_mean_meters'], axis=1, inplace=True)
X_train.drop(['Quakers'], axis=1, inplace=True)
X_train.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 17 to 6
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number.of.Bags        22 non-null     int64
#  1   Harvest.Year          22 non-null     int64
#  2   Fragrance...Aroma     22 non-null     float64
#  3   Flavor                22 non-null     float64
#  4   Aftertaste            22 non-null     float64
#  5   Salt...Acid           22 non-null     float64
#  6   Bitter...Sweet        22 non-null     float64
#  7   Mouthfeel             22 non-null     float64
#  8   Uniform.Cup           22 non-null     float64
#  9   Clean.Cup             22 non-null     float64
#  10  Balance               22 non-null     float64
#  11  Cupper.Points         22 non-null     float64
#  12  Total.Cup.Points      22 non-null     float64
#  13  Moisture              22 non-null     float64
#  14  Category.One.Defects  22 non-null     int64
#  15  Category.Two.Defects  22 non-null     int64
#  16  altitude_low_meters   19 non-null     float64
#  17  altitude_high_meters  19 non-null     float64
#  18  altitude_mean_log     19 non-null     float64
# dtypes: float64(15), int64(4)
# memory usage: 3.4 KB

# %%
altitude_low_meters_mean = X_train["altitude_low_meters"].mean()
altitude_high_meters_mean = X_train["altitude_high_meters"].mean()
altitude_mean_log_mean = X_train["altitude_mean_log"].mean()

# %%
# fillna with mean.. 
X_train["altitude_low_meters"] = X_train["altitude_low_meters"].fillna(altitude_low_meters_mean)
X_train["altitude_high_meters"] = X_train["altitude_high_meters"].fillna(altitude_high_meters_mean)
X_train["altitude_mean_log"] = X_train["altitude_mean_log"].fillna(altitude_mean_log_mean)

# %%
print(f"altitude low meters mean is {altitude_low_meters_mean}")
print(f"altitude_high_meters_mean is {altitude_high_meters_mean}")
print(f"altitude_mean_log_mean is {altitude_mean_log_mean}")
# Out:
# altitude low meters mean is 1500.3684210526317
# altitude_high_meters_mean is 1505.6315789473683
# altitude_mean_log_mean is 7.0571530664031155

# %% [markdown]
# ## Trainining the model

# %%
## in order to exemplify how the predict will work.. we will save the y_train
X_test.to_csv("data/X_test.csv")
y_test.to_csv("data/y_test.csv")

# %%
#training the model
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = reg.predict(X_train)
mse = mean_squared_error(y_train, y_train_pred)
print(mse)
# Out:
# 6.701014816713759e-28

# %%
#dropping Quakers column and unnamed
#changing one of the altitude to log and droping the original
X_test["altitude_mean_log"] = np.log(X_test["altitude_mean_meters"])
X_test.drop(['altitude_mean_meters'], axis=1, inplace=True)
X_test.drop(['Quakers'], axis=1, inplace=True)
X_test.drop(['Unnamed: 0'], axis=1, inplace=True)
# fillna with mean.. 
X_test["altitude_low_meters"] = X_test["altitude_low_meters"].fillna(altitude_low_meters_mean)
X_test["altitude_high_meters"] = X_test["altitude_high_meters"].fillna(altitude_high_meters_mean)
X_test["altitude_mean_log"] = X_test["altitude_mean_log"].fillna(altitude_mean_log_mean)

# %%
y_test_pred = reg.predict(X_test)
mse = mean_squared_error(y_test, y_test_pred)
print(mse)
# Out:
# 2.08680004794465e-27
